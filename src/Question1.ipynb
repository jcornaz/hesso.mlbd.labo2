# %% [markdown]
# # Question 1 #
#
# Implement the curvature_hist function

# %%
# %run init.py

# %%
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pylab as pl
from answers import curvature_hist

examples = [1, 13, 7]
#examples = [19, 44, 3, 6]
for i, idx in enumerate(examples): 
    pl.figure(figsize=(10, 5))
    img = load_img(meta.iloc[idx]['basename'])
    c = curvature_hist(img, step=10, plot=True)
    print c
# Out:
# [ 0.       0.04757  0.09513  0.1427   0.19026  0.23783  0.28539  0.33296
#   0.38052  0.42809  0.47565]
# [ 0.       0.02526  0.05052  0.07578  0.10104  0.12629  0.15155  0.17681
#   0.20207  0.22733  0.25259]
# [ 0.       0.02176  0.04352  0.06529  0.08705  0.10881  0.13057  0.15234
#   0.1741   0.19586  0.21762]
# C:\Users\Jonathan\Anaconda\lib\site-packages\skimage\util\dtype.py:107: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
