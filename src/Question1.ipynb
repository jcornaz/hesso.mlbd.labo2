# %% [markdown]
# # Question 1 #
#
# Implement the curvature_hist function

# %%
import mlbd
meta = mlbd.load_meta()
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pylab as pl
from mlbd import load_img
from answers import curvature_hist

examples = np.random.randint( len( meta ), size=50 )
for i, idx in enumerate(examples): 
    pl.figure(figsize=(10, 5))
    img = load_img(meta.iloc[idx]['basename'])
    c = curvature_hist(img, step=10, plot=True, vmin=0.03, vmax=0.30)
    print c
# Out:
# [ 0.15987  0.08777  0.05799  0.04937  0.04232  0.02351  0.00549  0.00157
#   0.       0.     ]
# [ 0.01071  0.00642  0.00535  0.00428  0.00964  0.01071  0.       0.       0.
#   0.     ]
# [ 0.29407  0.13305  0.07881  0.02797  0.00932  0.01186  0.00508  0.       0.
#   0.     ]
# [ 0.13086  0.09465  0.08889  0.05926  0.05432  0.08148  0.06008  0.00494
#   0.       0.     ]
# [ 0.20829  0.09643  0.06847  0.04822  0.01929  0.00579  0.00386  0.       0.
#   0.     ]
# [ 0.18558  0.13857  0.10373  0.06726  0.02998  0.01053  0.00162  0.       0.
#   0.     ]
# [ 0.23633  0.06605  0.01754  0.00516  0.00929  0.       0.       0.       0.
#   0.     ]
# [ 0.01653  0.00517  0.00413  0.00413  0.00517  0.01446  0.0031   0.       0.
#   0.     ]
# [ 0.19593  0.11251  0.08632  0.04268  0.02716  0.       0.       0.       0.
#   0.     ]
# [ 0.1352   0.10714  0.08503  0.10289  0.08333  0.03741  0.0017   0.       0.
#   0.     ]
# ...
