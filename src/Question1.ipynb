# %% [markdown]
# # Question 1 #
#
# Implement the curvature_hist function

# %%
import mlbd
meta = mlbd.load_meta()
# %pylab inline --no-import-all
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pylab as pl
from mlbd import load_img
from answers import curvature_hist

examples = np.random.randint( len( meta ), size=50 )
for i, idx in enumerate(examples): 
    pl.figure(figsize=(10, 5))
    img = load_img(meta.iloc[idx]['basename'])
    c = curvature_hist(img, step=10, plot=True, vmin=0.03, vmax=0.30)
    print c
# Out:
# [ 0.21919  0.14111  0.09784  0.02446  0.02352  0.       0.       0.       0.
#   0.     ]
# [ 0.0229   0.01037  0.00994  0.01037  0.01685  0.02593  0.00691  0.       0.
#   0.     ]
# [ 0.03484  0.01677  0.00387  0.00516  0.00774  0.01677  0.00258  0.       0.
#   0.     ]
# [ 0.16523  0.08262  0.03959  0.01893  0.03356  0.01893  0.0043   0.00258
#   0.00172  0.     ]
# [ 0.18769  0.10435  0.08108  0.09384  0.07057  0.03679  0.00976  0.       0.
#   0.     ]
# [ 0.21422  0.06234  0.01493  0.00966  0.00263  0.00176  0.       0.       0.
#   0.     ]
# [ 0.22147  0.14969  0.0908   0.0546   0.04049  0.01718  0.00123  0.       0.
#   0.     ]
# [ 0.01053  0.01263  0.00421  0.00316  0.00737  0.01368  0.00105  0.       0.
#   0.     ]
# [ 0.21355  0.10751  0.05449  0.05449  0.0486   0.02946  0.00589  0.       0.
#   0.     ]
# [ 0.03998  0.01209  0.01116  0.01069  0.02046  0.02836  0.00279  0.       0.
#   0.     ]
# [ 0.18165  0.0899   0.04541  0.04263  0.04171  0.05561  0.02317  0.00371
#   0.00185  0.     ]
# [ 0.20095  0.13365  0.07014  0.05024  0.03128  0.00095  0.       0.       0.
#   0.     ]
# [ 0.16401  0.07821  0.03645  0.03037  0.02733  0.03872  0.02202  0.00607
#   0.00152  0.00152]
# [ 0.26824  0.12994  0.02964  0.0076   0.00456  0.0038   0.00076  0.       0.
#   0.     ]
# [ 0.14138  0.10776  0.07414  0.06724  0.08103  0.05517  0.01552  0.00259
#   0.       0.     ]
# [ 0.02941  0.01493  0.01946  0.01855  0.02217  0.0086   0.00633  0.       0.
#   0.     ]
# [ 0.10949  0.03684  0.02572  0.02364  0.04414  0.06535  0.03024  0.0007
#   0.00104  0.     ]
# [ 0.2552   0.09452  0.02836  0.01512  0.01701  0.01701  0.00756  0.       0.
#   0.     ]
# [ 0.15129  0.11721  0.12469  0.09892  0.07149  0.04489  0.01081  0.00416
#   0.       0.00083]
# [ 0.09601  0.0356   0.01834  0.01546  0.04746  0.08882  0.03632  0.00144
#   0.00036  0.     ]
# [ 0.11954  0.05001  0.02446  0.02611  0.04314  0.05111  0.03215  0.0011
#   0.00055  0.00027]
# [ 0.15048  0.04098  0.03271  0.02307  0.03616  0.04408  0.01825  0.00034
#   0.       0.     ]
# [ 0.17718  0.11582  0.11322  0.09594  0.05704  0.02852  0.01124  0.       0.
#   0.     ]
# [ 0.01468  0.00629  0.00524  0.01468  0.01677  0.       0.       0.       0.
#   0.     ]
# [ 0.04627  0.01397  0.01091  0.01484  0.02532  0.03928  0.0048   0.00044
#   0.       0.     ]
# [ 0.11102  0.03268  0.01997  0.02179  0.05292  0.07263  0.02309  0.00026
#   0.       0.     ]
# [ 0.1626   0.03862  0.00711  0.0122   0.00508  0.       0.       0.       0.
#   0.     ]
# [ 0.15451  0.07187  0.03299  0.02986  0.04792  0.05625  0.02083  0.       0.
#   0.     ]
# [ 0.16495  0.0134   0.00722  0.0134   0.       0.       0.       0.       0.
#   0.     ]
# [ 0.18206  0.14298  0.11012  0.08526  0.04973  0.04529  0.00888  0.       0.
#   0.     ]
# [ 0.01135  0.00619  0.00413  0.0031   0.00929  0.00929  0.00206  0.       0.
#   0.     ]
# [ 0.19371  0.11111  0.09576  0.06871  0.04167  0.0212   0.00073  0.       0.
#   0.     ]
# [ 0.12486  0.06831  0.02128  0.0084   0.01568  0.02016  0.00168  0.       0.
#   0.     ]
# [ 0.0129   0.00538  0.00645  0.00323  0.00968  0.01505  0.       0.       0.
#   0.     ]
# [ 0.0064   0.00747  0.0064   0.00427  0.00961  0.00961  0.0032   0.       0.
#   0.     ]
# [ 0.17298  0.10579  0.05432  0.0143   0.02001  0.00143  0.       0.       0.
#   0.     ]
# [ 0.19946  0.08277  0.02035  0.00407  0.01764  0.00678  0.00271  0.00543
#   0.       0.     ]
# [ 0.13483  0.11306  0.05688  0.06039  0.10323  0.11938  0.04846  0.01966
#   0.00913  0.00211]
# [ 0.16401  0.07821  0.03645  0.03037  0.02733  0.03872  0.02202  0.00607
#   0.00152  0.00152]
# [ 0.24974  0.14984  0.06452  0.0333   0.00937  0.00624  0.00728  0.       0.
#   0.     ]
# [ 0.01037  0.01037  0.00519  0.00207  0.00622  0.01452  0.       0.       0.
#   0.     ]
# [ 0.23633  0.06605  0.01754  0.00516  0.00929  0.       0.       0.       0.
#   0.     ]
# [ 0.00406  0.01014  0.00507  0.00609  0.0142   0.00507  0.       0.       0.
#   0.     ]
# [ 0.13066  0.0561   0.02533  0.02533  0.05139  0.08324  0.03583  0.00109
#   0.00036  0.00036]
# [ 0.17067  0.13208  0.10892  0.11321  0.09091  0.03431  0.00515  0.       0.
#   0.     ]
# [ 0.22014  0.07305  0.02172  0.01185  0.00296  0.00494  0.00296  0.00099
#   0.       0.     ]
# [ 0.03103  0.01464  0.01639  0.01581  0.01698  0.03396  0.01112  0.00234
#   0.       0.     ]
# [ 0.01577  0.01052  0.01004  0.01243  0.01243  0.03107  0.00908  0.00096
#   0.       0.     ]
# [ 0.24576  0.20245  0.11582  0.03296  0.00565  0.00847  0.00753  0.00188
#   0.00094  0.     ]
# [ 0.01577  0.01052  0.01004  0.01243  0.01243  0.03107  0.00908  0.00096
#   0.       0.     ]
# /usr/share/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
